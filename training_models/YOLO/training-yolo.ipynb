# %%
from ultralytics import YOLO
import os 
from IPython.display import display, Image
from IPython import display
import cv2
display.clear_output()

# %%
model = YOLO("../../models/yolov8x-obb.pt")
# model = YOLO("./runs/obb/train2/weights/best.pt")

# %%
results = model.train(data='../../datasets-reduced/megaset/data.yaml', epochs=6, imgsz=1024, device=0, plots=True, batch=-1, dropout=0.0001, weight_decay=0.0015, optimizer="SGD", patience=3, single_cls=True, close_mosaic=2)
# results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.14 🚀 Python-3.9.18 torch-2.2.0 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# engine/trainer: task=obb, mode=train, model=../../models/yolov8x-obb.pt, data=../../datasets-reduced/megaset/data.yaml, epochs=6, time=None, patience=3, batch=-1, imgsz=1024, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=train5, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=True, rect=False, cos_lr=False, close_mosaic=2, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0001, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0015, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/obb/train5
# Overriding model.yaml nc=15 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = model.train(data='../../datasets-reduced/megaset/data.yaml', epochs=6, imgsz=1024, device=0, plots=True, batch=-1, dropout=0.0001, weight_decay=0.0015, optimizer="SGD", patience=3, single_cls=True, close_mosaic=2)
#       2 # results = model.train(resume=True)
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/engine/model.py:584, in Model.train(self, trainer, **kwargs)
#     582 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     583 if not args.get("resume"):  # manually set model only if not resuming
# --> 584     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     585     self.model = self.trainer.model
#     587     if SETTINGS["hub"] is True and not self.session:
#     588         # Create a model in HUB
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/models/yolo/obb/train.py:33, in OBBTrainer.get_model(self, cfg, weights, verbose)
#      31 def get_model(self, cfg=None, weights=None, verbose=True):
#      32     """Return OBBModel initialized with specified config and weights."""
# ---> 33     model = OBBModel(cfg, ch=3, nc=self.data["nc"], verbose=verbose and RANK == -1)
#      34     if weights:
#      35         model.load(weights)
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/nn/tasks.py:349, in OBBModel.__init__(self, cfg, ch, nc, verbose)
#     347 def __init__(self, cfg="yolov8n-obb.yaml", ch=3, nc=None, verbose=True):
#     348     """Initialize YOLOv8 OBB model with given config and parameters."""
# --> 349     super().__init__(cfg=cfg, ch=ch, nc=nc, verbose=verbose)
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/nn/tasks.py:281, in DetectionModel.__init__(self, cfg, ch, nc, verbose)
#     279     LOGGER.info(f"Overriding model.yaml nc={self.yaml['nc']} with nc={nc}")
#     280     self.yaml["nc"] = nc  # override YAML value
# --> 281 self.model, self.save = parse_model(deepcopy(self.yaml), ch=ch, verbose=verbose)  # model, savelist
#     282 self.names = {i: f"{i}" for i in range(self.yaml["nc"])}  # default names dict
#     283 self.inplace = self.yaml.get("inplace", True)
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/nn/tasks.py:894, in parse_model(d, ch, verbose)
#     891 else:
#     892     c2 = ch[f]
# --> 894 m_ = nn.Sequential(*(m(*args) for _ in range(n))) if n > 1 else m(*args)  # module
#     895 t = str(m)[8:-2].replace("__main__.", "")  # module type
#     896 m.np = sum(x.numel() for x in m_.parameters())  # number params
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:220, in C2f.__init__(self, c1, c2, n, shortcut, g, e)
#     218 self.cv1 = Conv(c1, 2 * self.c, 1, 1)
#     219 self.cv2 = Conv((2 + n) * self.c, c2, 1)  # optional act=FReLU(c2)
# --> 220 self.m = nn.ModuleList(Bottleneck(self.c, self.c, shortcut, g, k=((3, 3), (3, 3)), e=1.0) for _ in range(n))
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/torch/nn/modules/container.py:279, in ModuleList.__init__(self, modules)
#     277 super().__init__()
#     278 if modules is not None:
# --> 279     self += modules
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/torch/nn/modules/container.py:320, in ModuleList.__iadd__(self, modules)
#     319 def __iadd__(self, modules: Iterable[Module]) -> Self:
# --> 320     return self.extend(modules)
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/torch/nn/modules/container.py:401, in ModuleList.extend(self, modules)
#     398     raise TypeError("ModuleList.extend should be called with an "
#     399                     "iterable, but got " + type(modules).__name__)
#     400 offset = len(self)
# --> 401 for i, module in enumerate(modules):
#     402     self.add_module(str(offset + i), module)
#     403 return self
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:220, in <genexpr>(.0)
#     218 self.cv1 = Conv(c1, 2 * self.c, 1, 1)
#     219 self.cv2 = Conv((2 + n) * self.c, c2, 1)  # optional act=FReLU(c2)
# --> 220 self.m = nn.ModuleList(Bottleneck(self.c, self.c, shortcut, g, k=((3, 3), (3, 3)), e=1.0) for _ in range(n))
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:330, in Bottleneck.__init__(self, c1, c2, shortcut, g, k, e)
#     328 c_ = int(c2 * e)  # hidden channels
#     329 self.cv1 = Conv(c1, c_, k[0], 1)
# --> 330 self.cv2 = Conv(c_, c2, k[1], 1, g=g)
#     331 self.add = shortcut and c1 == c2
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/ultralytics/nn/modules/conv.py:44, in Conv.__init__(self, c1, c2, k, s, p, g, d, act)
#      42 """Initialize Conv layer with given arguments including activation."""
#      43 super().__init__()
# ---> 44 self.conv = nn.Conv2d(c1, c2, k, s, autopad(k, p, d), groups=g, dilation=d, bias=False)
#      45 self.bn = nn.BatchNorm2d(c2)
#      46 self.act = self.default_act if act is True else act if isinstance(act, nn.Module) else nn.Identity()
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/torch/nn/modules/conv.py:447, in Conv2d.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     445 padding_ = padding if isinstance(padding, str) else _pair(padding)
#     446 dilation_ = _pair(dilation)
# --> 447 super().__init__(
#     448     in_channels, out_channels, kernel_size_, stride_, padding_, dilation_,
#     449     False, _pair(0), groups, bias, padding_mode, **factory_kwargs)
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/torch/nn/modules/conv.py:141, in _ConvNd.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode, device, dtype)
#     138 else:
#     139     self.register_parameter('bias', None)
# --> 141 self.reset_parameters()
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/torch/nn/modules/conv.py:147, in _ConvNd.reset_parameters(self)
#     143 def reset_parameters(self) -> None:
#     144     # Setting a=sqrt(5) in kaiming_uniform is the same as initializing with
#     145     # uniform(-1/sqrt(k), 1/sqrt(k)), where k = weight.size(1) * prod(*kernel_size)
#     146     # For more details see: https://github.com/pytorch/pytorch/issues/15314#issuecomment-477448573
# --> 147     init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#     148     if self.bias is not None:
#     149         fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# File ~/anaconda3/envs/cs229proj/lib/python3.9/site-packages/torch/nn/init.py:459, in kaiming_uniform_(tensor, a, mode, nonlinearity, generator)
#     457 bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     458 with torch.no_grad():
# --> 459     return tensor.uniform_(-bound, bound, generator=generator)
#
# KeyboardInterrupt:

# %%
# Validate the model
metrics = model.val(data='../../datasets-reduced/megaset/data.yaml', split="test", device=0, batch=16, save_json=True)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps   # a list contains map50-95(B) of each category
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.9.18 torch-2.2.0 CUDA:0 (NVIDIA GeForce RTX 4090, 24195MiB)
# YOLOv8x-obb summary (fused): 287 layers, 69450054 parameters, 0 gradients, 263.2 GFLOPs
# val: Scanning /home/meribejayson/Desktop/SharkCNN/datasets-reduced/megaset/test/labels.cache... 13087 images, 7291 backgrounds, 0 corrupt: 100%|██████████| 13087/13087 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 818/818 [02:53<00:00,  4.72it/s]
#                    all      13087      16327      0.245      0.325      0.271     0.0759
# Speed: 0.1ms preprocess, 12.1ms inference, 0.0ms loss, 0.5ms postprocess per image
# Saving runs/obb/train42/predictions.json...
# Results saved to runs/obb/train42
# array([   0.075898])

# %%
# Load the YOLOv8 model
model = YOLO('./runs/obb/train3/weights/best.pt')

# Open the video file
video_path = "/home/meribejayson/Desktop/SharkCNN/test-vid/test.mp4"
video_path_2 = "/home/meribejayson/Desktop/SharkCNN/test-vid/test_2.mp4"
video_path_3 = "/home/meribejayson/Desktop/SharkCNN/test-vid/train.mp4"
cap = cv2.VideoCapture(video_path_2)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 544x1024 (no detections), 63.2ms
# Speed: 1.9ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 12.1ms
# Speed: 1.4ms preprocess, 12.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.0ms
# Speed: 1.4ms preprocess, 10.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.0ms
# Speed: 1.4ms preprocess, 10.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.7ms preprocess, 10.9ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 1.3ms preprocess, 11.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.3ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.9ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.3ms preprocess, 11.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 2.1ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.6ms
# Speed: 2.4ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 2.3ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.8ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 2.3ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 2.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# ...
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 1.7ms preprocess, 11.7ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.2ms
# Speed: 1.6ms preprocess, 10.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.7ms preprocess, 11.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 12.0ms
# Speed: 2.2ms preprocess, 12.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.7ms preprocess, 11.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.9ms
# Speed: 1.6ms preprocess, 11.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.6ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.3ms
# Speed: 2.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 1024)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 26
#      23     cv2.imshow("YOLOv8 Inference", annotated_frame)
#      25     # Break the loop if 'q' is pressed
# ---> 26     if cv2.waitKey(1) & 0xFF == ord("q"):
#      27         break
#      28 else:
#      29     # Break the loop if the end of the video is reached
#
# KeyboardInterrupt:
